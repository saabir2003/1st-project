# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#lambda function

# %%
#try except block
try:
    #a=b
    num=int(input("enter an integer"))
    result=1/num
except TypeError as ex:
    print(ex)
except ValueError as ex1:
    print(ex1)
except ZeroDivisionError as ex2:
    print(ex2)
except Exception as ex3:
    print(ex3)
else:
    print("No Errors")
    print(result)
finally:
    print("code executed \nerror or not code is executed")
# Out:
# raw_input was called, but this frontend does not support input requests.
# code executed
# error or not code is executed

# %%
#print(dir(car))

# %%
#saabir.printdetails()

# %%
class BankAccount:
    def __init__(self,i,name,balance):
        self.i=i
        self.name=name
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print("deposited suceesfully")
        self.printbalance()
    def withdraw(self,amount):
        if self.balance<amount:
            print("balance insufficent")
        else:
            self.balance-=amount
            print("amount withdrawn")
            self.printbalance()
    def printbalance(self):
        print(self.balance)
b1=BankAccount(1,"saabir",10000)
b2=BankAccount(1,"ayesha",13000)

# %%
b1.deposit(10000)
# Out:
# deposited suceesfully
# 20000

# %%
b1.name
# Out:
# 'saabir'

# %%
# inheritance in python
# single class inheritance
class transaction(BankAccount):
    def __init__(self,i,name,balance,amount,credit):
        super().__init__(i,name,balance)
        self.amount=amount
        self.credit=credit
    def printl(self):
        print(self.i,self.balance,self.amount,self.credit,self.name)

# %%
t1=transaction(12,"saabir",100000,10000,True)

# %%
t1.printl()
# Out:
# 12 100000 10000 True saabir

# %%
t1.deposit(10000)
# Out:
# deposited suceesfully
# 110000

# %%
t1.printbalance()
# Out:
# 110000

# %%
class data:
    def __init__(self,dname,data1):
        self.dname=dname
        self.data1=data1
    def printdata():
        print(self.dname,self.data1)

# %%
#multipple inhertiance
# when a class nherits more than one base class
class Item(data):
    def __init__(self,name,Price,Size,data1,dname):
        data.__init__(self,dname,data1)
        self.name=name
        self.Price=Price
        self.Size=Size
    def printdetails(self):
        print(self.name,self.Price,self.Size)
I1=Item("butter",20,"M",30,"KB")
I1.printdetails()
# Out:
# butter 20 M

# %%
class customer(data):
    def __init__(self,cname,dname,data1):
        data.__init__(self,dname,data1)
        self.cname=cname
    def printcname(self):
        print(self.cname)
C1=customer("saabir","MB",45)
C1.printcname()
# Out:
# saabir

# %%
class Order(Item,customer):
    def __init__(self,name,Price,Size,cname,order_id,data1,dname):
        Item.__init__(self,name,Price,Size,data1,dname)
        customer.__init__(self,cname,data1,dname)
        #data.__init__(self,data1,dname)
        self.order_id=order_id
    def printdetails(self):
        print(self.name,self.Price,self.Size,self.order_id,self.cname,self.data1,self.dname)
O1=Order("butter",20,"M","saabir",23,67,"GB")

# %%
O1.printdetails()
# Out:
# butter 20 M 23 saabir GB 67
